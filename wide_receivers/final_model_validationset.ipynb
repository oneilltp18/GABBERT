# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Our Data

# %%
## I will first be importing my pivoted catcherr csv in order to add the
## features needed to save the final csv
df = pd.read_csv('https://raw.githubusercontent.com/oneilltp18/GABBERT/master/wide_receivers/pivot_catcherr.csv')

## Now I am importing the pivoted csv of just the people who were rookies in
## 2013, this is our overall validation set that we are predicting
rooks_df = pd.read_csv('https://raw.githubusercontent.com/oneilltp18/GABBERT/master/wide_receivers/rooks_df.csv')

#######
####### All the below code has been commented out since it was only necessary the first time through, as
####### the csv has been saved over

# #need to drop the unnamed first column when we import csv's
# df.drop('Unnamed: 0', axis = 1, inplace = True)

# going to set the index to the name of the player
df.set_index(df.name, inplace = True)


# need to drop the name column as it is now the index
df.drop('name', axis = 1, inplace = True)


# ## I also need to drop a couple year 4 stats that snuck in for some reason
# df.drop(['receptions_3', 'rec_yards_3'], axis = 1, inplace = True)

# # Also I will create categories for player season_3 ratings (bins)
# bins = [-1, 10, 30, 65, 200]
# labels = ['below average', 'league_average', 'quality starter', 'all_pro']
# df['categories'] =  pd.cut(df['compilation_3'], bins, labels=labels)


# ###### I am now rewriting over the pivot_catcherr csv with our final version
# df.to_csv('/Users/TerryONeill/Terry_git/Capstone/GABBERT/wide_receivers/pivot_catcherr.csv')

df.head()
# Out:
#                  season_0  season_1  season_2  age_0  age_1  age_2  weight_0  \
# name
# A.J. Green         2011.0    2012.0    2013.0   23.0   24.0   25.0     205.0
# A.J. Jenkins       2012.0    2013.0    2014.0   23.0   24.0   25.0     192.0
# Aaron Brown        2009.0    2010.0    2011.0   24.0   25.0   26.0     196.0
# Aaron Halterman    2007.0    2008.0    2009.0   25.0   26.0   27.0     255.0
# Aaron Moorehead    2003.0    2004.0    2005.0   23.0   24.0   25.0     200.0
#
#                  weight_1  weight_2  bmi_0       ...         compilation_0  \
# name                                             ...
# A.J. Green          205.0     205.0   25.0       ...             53.006410
# A.J. Jenkins        192.0     192.0   26.0       ...              0.000000
# Aaron Brown         196.0     196.0   26.6       ...              1.007213
# Aaron Halterman     255.0     255.0   30.2       ...              0.030196
# Aaron Moorehead     200.0     200.0   25.0       ...              0.240777
#
#                  compilation_1  compilation_2  compilation_3  avg_starts  \
# name
# A.J. Green           98.471570      82.935491      59.741763    1.000000
# A.J. Jenkins          0.597268       0.000000       0.000000    0.020833
# Aaron Brown           0.000000       0.000000       0.000000    0.044444
# Aaron Halterman       0.000000       0.000000       0.000000    0.000000
# Aaron Moorehead       0.025880       0.222518       0.274562    0.000000
#
#                  dpis  dpi_yards  year_1_growth  year_2_growth  \
# name
# A.J. Green        0.0        0.0       9.264454     -13.711468
# A.J. Jenkins      0.0        0.0       0.121706      -0.527123
# Aaron Brown       0.0        0.0      -0.205240       0.000000
# Aaron Halterman   0.0        0.0      -0.006153       0.000000
# Aaron Moorehead   0.0        0.0      -0.043790       0.173544
#
#                       categories
# name
# A.J. Green       quality starter
# A.J. Jenkins       below average
# Aaron Brown        below average
# Aaron Halterman    below average
# Aaron Moorehead    below average
#
# [5 rows x 151 columns]

# %%
## I need to set the index and drop the name col for the rookies as well
# rooks_df.set_index(rooks_df['name'], inplace = True)
# rooks_df.head()

rooks_df.index = rooks_df.name.values
rooks_df.head()
# Out:
#                                         name  season_0  season_1  season_2  \
# Aaron Dobson                    Aaron Dobson    2013.0    2014.0    2015.0
# Ace Sanders                      Ace Sanders    2013.0    2014.0    2015.0
# Ben Watson                        Ben Watson    2013.0    2014.0    2015.0
# Chris Hogan                      Chris Hogan    2013.0    2014.0    2015.0
# Cordarrelle Patterson  Cordarrelle Patterson    2013.0    2014.0    2015.0
#
#                        age_0  age_1  age_2  weight_0  weight_1  weight_2  \
# Aaron Dobson            22.0   23.0   24.0     210.0     210.0     210.0
# Ace Sanders             22.0   23.0   24.0     173.0     173.0     173.0
# Ben Watson              33.0   34.0   35.0     255.0     255.0     255.0
# Chris Hogan             25.0   26.0   27.0     220.0     220.0     220.0
# Cordarrelle Patterson   22.0   23.0   24.0     216.0     216.0     216.0
#
#                            ...        td_points_1  td_points_2  compilation_0  \
# Aaron Dobson               ...           0.000000     0.000000      10.546819
# Ace Sanders                ...           0.000000     0.000000      12.428353
# Ben Watson                 ...           0.000000     0.000000       0.000000
# Chris Hogan                ...           0.376265     0.094066       0.327132
# Cordarrelle Patterson      ...           0.063633     0.000000      19.582420
#
#                        compilation_1  compilation_2  avg_starts  dpis  \
# Aaron Dobson                0.083563       0.966747    0.458333   7.0
# Ace Sanders                 0.229302       0.000000    0.088889   0.0
# Ben Watson                  0.000000       0.000000    0.155556   0.0
# Chris Hogan                10.805001      10.623025    0.125000   1.0
# Cordarrelle Patterson       7.735541       0.063590    0.291667   6.0
#
#                        dpi_yards  year_1_growth  year_2_growth
# Aaron Dobson               147.0      -2.527641       0.476617
# Ace Sanders                  0.0      -2.946962      -0.123745
# Ben Watson                   0.0       0.000000       0.000000
# Chris Hogan                  5.0       2.531171      -0.098205
# Cordarrelle Patterson      160.0      -2.861887      -4.140231
#
# [5 rows x 150 columns]

# %%
rooks_df.drop('name', axis = 1, inplace = True)
rooks_df.head()
# Out:
#                        season_0  season_1  season_2  age_0  age_1  age_2  \
# Aaron Dobson             2013.0    2014.0    2015.0   22.0   23.0   24.0
# Ace Sanders              2013.0    2014.0    2015.0   22.0   23.0   24.0
# Ben Watson               2013.0    2014.0    2015.0   33.0   34.0   35.0
# Chris Hogan              2013.0    2014.0    2015.0   25.0   26.0   27.0
# Cordarrelle Patterson    2013.0    2014.0    2015.0   22.0   23.0   24.0
#
#                        weight_0  weight_1  weight_2  bmi_0      ...        \
# Aaron Dobson              210.0     210.0     210.0   26.2      ...
# Ace Sanders               173.0     173.0     173.0   27.1      ...
# Ben Watson                255.0     255.0     255.0   31.9      ...
# Chris Hogan               220.0     220.0     220.0   29.0      ...
# Cordarrelle Patterson     216.0     216.0     216.0   27.7      ...
#
#                        td_points_1  td_points_2  compilation_0  compilation_1  \
# Aaron Dobson              0.000000     0.000000      10.546819       0.083563
# Ace Sanders               0.000000     0.000000      12.428353       0.229302
# Ben Watson                0.000000     0.000000       0.000000       0.000000
# Chris Hogan               0.376265     0.094066       0.327132      10.805001
# Cordarrelle Patterson     0.063633     0.000000      19.582420       7.735541
#
#                        compilation_2  avg_starts  dpis  dpi_yards  \
# Aaron Dobson                0.966747    0.458333   7.0      147.0
# Ace Sanders                 0.000000    0.088889   0.0        0.0
# Ben Watson                  0.000000    0.155556   0.0        0.0
# Chris Hogan                10.623025    0.125000   1.0        5.0
# Cordarrelle Patterson       0.063590    0.291667   6.0      160.0
#
#                        year_1_growth  year_2_growth
# Aaron Dobson               -2.527641       0.476617
# Ace Sanders                -2.946962      -0.123745
# Ben Watson                  0.000000       0.000000
# Chris Hogan                 2.531171      -0.098205
# Cordarrelle Patterson      -2.861887      -4.140231
#
# [5 rows x 149 columns]

# %%
## I want to create a list of the column names associated with a players
## first and second year stats, the following loop will go through and add
## all these stats to the list year_12

year_12 = []
for col in df:
    if col == 'year_1_growth':
        pass
    else:
        if '_0' in col:
            year_12.append(col)
        if '_1' in col:
            year_12.append(col)
            
            
## I also want to create a list of the rest of the col names (year3 data)
year_3 = []
for col in df:
    if col not in year_12:
        year_3.append(col)
        
year_3
# Out:
# ['season_2',
#  'age_2',
#  'weight_2',
#  'bmi_2',
#  'games_2',
#  'rush_atts_2',
#  'rush_yds_2',
#  'rush_y/a_2',
#  'rush_tds_2',
#  'rush_ypg_2',
#  'targets_2',
#  'receptions_2',
#  'rec_yards_2',
#  'yards/reception_2',
#  'rec_tds_2',
#  'rec_ypg_2',
#  'ctch_pct_2',
#  'y/tgt_2',
#  'fumbles_2',
#  'fumbles_recovered_2',
#  'fum_ret_yds_2',
#  'fum_tds_2',
#  'forced_fumbles_2',
#  'pro_bowls_2',
#  'all_pros_2',
#  '100yd_gms_2',
#  'first_down_ctchs_2',
#  'first_down_ctchpct_2',
#  'long_ctch_2',
#  'drops_2',
#  'EYds_2',
#  'DVOA_2',
#  'DYAR_2',
#  '40 Yard_2',
#  'rookie_age_2',
#  'rookie_season_2',
#  'height_inches_2',
#  'start_ratio_2',
#  'dpis_drawn_2',
#  'dpi_yards_2',
#  'pct_team_tgts_2',
#  'pct_team_receptions_2',
#  'pct_of_team_passyards_2',
#  'pct_team_touchdowns_2',
#  'dropK_2',
#  'yacK_2',
#  'td_points_2',
#  'compilation_2',
#  'compilation_3',
#  'avg_starts',
#  'dpis',
#  'dpi_yards',
#  'year_1_growth',
#  'year_2_growth',
#  'categories']

# %%
## I am going to repeat this process for the rookie data as well
rooksyear_12 = []
for col in rooks_df:
    if col == 'year_1_growth':
        pass
    else:
        if '_0' in col:
            rooksyear_12.append(col)
        if '_1' in col:
            rooksyear_12.append(col)
            
            
## I also want to create a list of the rest of the col names (year3 data)
rooksyear_3 = []
for col in rooks_df:
    if col not in rooksyear_12:
        rooksyear_3.append(col)
        
rooksyear_3
# Out:
# ['season_2',
#  'age_2',
#  'weight_2',
#  'bmi_2',
#  'games_2',
#  'rush_atts_2',
#  'rush_yds_2',
#  'rush_y/a_2',
#  'rush_tds_2',
#  'rush_ypg_2',
#  'targets_2',
#  'receptions_2',
#  'rec_yards_2',
#  'yards/reception_2',
#  'rec_tds_2',
#  'rec_ypg_2',
#  'ctch_pct_2',
#  'y/tgt_2',
#  'fumbles_2',
#  'fumbles_recovered_2',
#  'fum_ret_yds_2',
#  'fum_tds_2',
#  'forced_fumbles_2',
#  'pro_bowls_2',
#  'all_pros_2',
#  '100yd_gms_2',
#  'first_down_ctchs_2',
#  'first_down_ctchpct_2',
#  'long_ctch_2',
#  'drops_2',
#  'EYds_2',
#  'DVOA_2',
#  'DYAR_2',
#  '40 Yard_2',
#  'rookie_age_2',
#  'rookie_season_2',
#  'height_inches_2',
#  'start_ratio_2',
#  'dpis_drawn_2',
#  'dpi_yards_2',
#  'pct_team_tgts_2',
#  'pct_team_receptions_2',
#  'pct_of_team_passyards_2',
#  'pct_team_touchdowns_2',
#  'dropK_2',
#  'yacK_2',
#  'td_points_2',
#  'compilation_2',
#  'avg_starts',
#  'dpis',
#  'dpi_yards',
#  'year_1_growth',
#  'year_2_growth']

# %% [markdown]
# # PCA

# %%
## I now want to perform PCA on all the year 1 and 2 stats columns
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# I am creating a dataframe of the scaled values of the year 1 and 2 columns
pca_df = scale(df[year_12])

# doing the same thing for the rookie data
rookspca_df = scale(rooks_df[rooksyear_12])

# %%
## creating the covariance matrix - this explains the variance between the different
## features within our dataframe

## for example, the value in the i,j position within the matrix explains the variance
## between the ith and the jth elements of a random vector, or between our features
cov_mat = np.cov(pca_df.T)

## creating my eigenvalues and corresponding eigenvectors
eigenValues, eigenVectors = np.linalg.eig(cov_mat)

## creating the eigenpairs - just pairing the eigenvalue with its eigenvector
eigenPairs = [(np.abs(eigenValues[i]), eigenVectors[:,i]) for i in range(len(eigenValues))]

# %%
## loop through the eigenpairs and printing out the first row (eigenvalue)
## this is also seen in the code block above but just wanted to loop through again
## as it is a bit more clear like this
## I am also creating a list of the eigenvalues in ascending order to be able to reference it
sort_values = []
for i in eigenPairs:
    print i[0]
    sort_values.append(i[0])
# Out:
# 31.1004172447
# 8.37699654955
# 5.68144617858
# 4.66851300718
# 4.30875326557
# 3.54751063564
# 2.85102279075
# 2.77468351685
# 2.4530634271
# 1.98353980126
# 1.8873361868
# 1.81354476181
# 1.46265719107
# 1.38724426312
# 1.22216310882
# 1.14299603062
# 1.08148128461
# 1.01553250699
# 1.00863793646
# 0.995798092837
# 0.912404972757
# 0.935055853353
# 0.852467904883
# 0.82253148254
# 0.778186873741
# 0.700528141975
# 0.671373787536
# 0.641147666505
# 0.610736725571
# 0.561725403211
# 0.538202333045
# 0.493854700223
# 0.455623298126
# 0.429498771074
# 0.404955434107
# 0.391863073062
# 0.364838926175
# 0.350647228352
# 0.336641834748
# 0.325059011605
# 0.291350446114
# 0.265907321403
# 0.259968155731
# 0.236963353397
# 0.233805156533
# 0.196417720057
# 0.207677376759
# 0.212154622742
# 0.167335408622
# 0.152283964168
# 0.170452783412
# 0.141191684846
# 0.121390989116
# 0.116682582569
# 0.107937607097
# 0.10285217139
# 0.0744391773946
# 0.0725376329156
# 0.0670437039671
# 0.0570709739462
# 0.0534423623818
# 0.0507257642628
# 0.0468117789775
# 0.0438166348696
# 0.0406018410038
# 0.0260903560814
# 0.0323898243667
# 0.0332973234385
# 0.0238793980863
# 0.02301596541
# 0.0197147710121
# 0.0200828437547
# 0.0159772609857
# 0.013125547053
# 0.0142709540706
# 0.00748076537516
# 0.00864717045044
# 0.00901046762047
# 0.00508549309608
# 0.00409903156335
# 0.00574475480506
# 0.010194019714
# 0.00128681310784
# 0.000796033726134
# 0.000386859088828
# 0.00206017052948
# 0.00203990011365
# 1.71329422875e-15
# 1.71329422875e-15
# 2.47730466143e-16
# 3.35124309401e-16
# 2.55315428019e-16
# 6.79574252254e-17
# 2.02348900548e-18
# 2.02348900548e-18
# 2.3530356211e-18

# %%
## we have the eigenvalues above showing us feature correlation explanation, but it helps
## to see the cumulative variance explained as well, which i can show below

## need to sum the eigen values to get percentages
sumEigenvalues = sum(eigenValues)

## this is a percentage explanation
variance_explained = [(i/sumEigenvalues)*100 for i in sort_values]
variance_explained
# Out:
# [(32.359116279836726+0j),
#  (8.7160311480493959+0j),
#  (5.9113862069273804+0j),
#  (4.8574575081825442+0j),
#  (4.4831375362072121+0j),
#  (3.6910858223937617+0j),
#  (2.9664096554201969+0j),
#  (2.8869807711852871+0j),
#  (2.5523440426776745+0j),
#  (2.0638178121340998+0j),
#  (1.9637206358769428+0j),
#  (1.8869427173385842+0j),
#  (1.5218539915695846+0j),
#  (1.4433889444515642+0j),
#  (1.2716266100203817+0j),
#  (1.18925547432853+0j),
#  (1.1252510976830974+0j),
#  (1.0566332348866609+0j),
#  (1.0494596266412299+0j),
#  (1.0361001276527073+0j),
#  (0.94933191331187661+0j),
#  (0.97289952249415923+0j),
#  (0.88696906674481468+0j),
#  (0.85582105467789416+0j),
#  (0.80968172666764993+0j),
#  (0.72887998334834792+0j),
#  (0.69854569111239528+0j),
#  (0.66709625564496899+0j),
#  (0.63545452022681326+0j),
#  (0.58445960698173749+0j),
#  (0.55998450889069151+0j),
#  (0.51384203446880494+0j),
#  (0.47406332744135093+0j),
#  (0.4468814860535546+0j),
#  (0.42134482882640151+0j),
#  (0.40772259250433651+0j),
#  (0.379604721782626+0j),
#  (0.36483865621975553+0j),
#  (0.35026643499765076+0j),
#  (0.33821483073867276+0j),
#  (0.30314200898987304+0j),
#  (0.27666914772343143+0j),
#  (0.27048961157549811+0j),
#  (0.24655375670011001+0j),
#  (0.24326774099300114+0j),
#  (0.2043671566435239+0j),
#  (0.21608251523950839+0j),
#  (0.22074096474591021+0j),
#  (0.1741078231436349+0j),
#  (0.15844721520287408+0j),
#  (0.17735136462157608+0j),
#  (0.14690600810023605+0j),
#  (0.12630393673514409+0j),
#  (0.1214049711125704+0j),
#  (0.11230606816417991+0j),
#  (0.10701481422085389+0j),
#  (0.077451886838988973+0j),
#  (0.075473382871636019+0j),
#  (0.069757103109930177+0j),
#  (0.05938075581412957+0j),
#  (0.055605286738466875+0j),
#  (0.052778742202884685+0j),
#  (0.04870634973411913+0j),
#  (0.045589985869933569+0j),
#  (0.042245082562044893+0j),
#  (0.027146287446134041+0j),
#  (0.033700708409087246+0j),
#  (0.034644935869284126+0j),
#  (0.02484584734946638+0j),
#  (0.023947469744045404+0j),
#  (0.020512669093471898+0j),
#  (0.020895638511032932+0j),
#  (0.016623894207018368+0j),
#  (0.013656765437680107+0j),
#  (0.014848529476638568+0j),
#  (0.0077835276206141548+0j),
#  (0.0089971395526707142+0j),
#  (0.0093751401202066941+0j),
#  (0.0052913136547792072+0j),
#  (0.0042649279573707321+0j),
#  (0.0059772570661362611+0j),
#  (0.01060659304630533+0j),
#  (0.0013388931299307802+0j),
#  (0.00082825087856356521+0j),
#  (0.00040251608654605158+0j),
#  (0.0021435499464532871+0j),
#  (0.0021224591444323477+0j),
#  (1.7826348351982434e-15+0j),
#  (1.7826348351982434e-15+0j),
#  (2.5775663705398123e-16+0j),
#  (3.486874922209662e-16+0j),
#  (2.656485782256795e-16+0j),
#  (7.0707804581573318e-17+0j),
#  (2.1053838443427752e-18+0j),
#  (2.1053838443427752e-18+0j),
#  (2.4482679018324897e-18+0j)]

# %%
### based on the above results, it seems that sticking to 25 features would be a decent
## cutoff point since the variance explained altogether reaches 85%

## this can very easily be manipulated by changing n_components adn then adding/subtracting
## columns to the dataframe in the code block below

## instantiate
pca = PCA(n_components = 25)

## fit and transform the standardized data
pca_model = pca.fit(pca_df)
pca_cols = pca_model.transform(pca_df)

## Here I am fitting the rookie data to the training PCA fit
rooks_pca_cols = pca_model.transform(rookspca_df)

# %%
## Here I am simply creating the column headers for the pca features
pca_col_list = []

for i in range(1, 26):
    pca_col_list.append('pca_'+str(i))
    
## going to organize the columns into dataframe for organization
## I am going to set the index of our pca dataframe to the names 
## of the related player
pca_df = pd.DataFrame(pca_cols, index = df.index, columns = pca_col_list)
## doing the same for the rookie information
rookspca_df = pd.DataFrame(rooks_pca_cols, index = rooks_df.index, columns = pca_col_list)
##previewing dataframe
pca_df.head()
rookspca_df.head()
# Out:
#                           pca_1     pca_2     pca_3     pca_4     pca_5  \
# Aaron Dobson           3.343230  3.234599  0.061489  1.126353 -4.016023
# Ace Sanders            2.086004  0.403029 -1.913178 -1.483139 -2.963584
# Ben Watson            -3.366994  5.500858  2.811695 -0.870495  4.748690
# Chris Hogan            2.218197 -3.002587  2.014100 -0.540094  3.537569
# Cordarrelle Patterson  8.507742  2.421352 -6.822007 -0.053077 -0.554181
#
#                           pca_6     pca_7     pca_8     pca_9    pca_10  \
# Aaron Dobson          -0.169113  1.543474 -0.543079 -1.153439 -0.406454
# Ace Sanders            0.108360  0.043014  0.066580  0.544618 -2.025070
# Ben Watson            -1.464372 -2.275484  4.188110 -2.096872 -0.183451
# Chris Hogan           -1.209184 -1.251494  0.238614 -0.536139  0.352101
# Cordarrelle Patterson -0.596962 -2.097737 -4.468785 -3.603206  2.877413
#
#                          ...       pca_16    pca_17    pca_18    pca_19  \
# Aaron Dobson             ...     1.394733 -2.316849  0.205744  1.563473
# Ace Sanders              ...    -0.844651 -1.592364  0.204843 -0.401870
# Ben Watson               ...     0.089196  0.051414 -0.481466 -1.082286
# Chris Hogan              ...    -0.075203  0.274858  0.091943 -0.020489
# Cordarrelle Patterson    ...     4.520804  0.450631 -1.594856  1.232573
#
#                          pca_20    pca_21    pca_22    pca_23    pca_24  \
# Aaron Dobson           2.237633  0.439652  0.549938  0.494690  2.316730
# Ace Sanders           -0.477640  2.116592  0.029834  1.559471  0.755661
# Ben Watson            -0.281499 -0.700152 -0.536205 -0.541687 -0.305282
# Chris Hogan           -0.620393 -0.351823  0.740131  0.053656  1.088257
# Cordarrelle Patterson -1.028965 -2.421642 -1.128343  1.775323 -1.143569
#
#                          pca_25
# Aaron Dobson          -0.036733
# Ace Sanders           -1.285792
# Ben Watson             0.665143
# Chris Hogan            0.861699
# Cordarrelle Patterson -0.687833
#
# [5 rows x 25 columns]

# %% [markdown]
# # Year 3 Stats Feature Selection

# %%
from sklearn.feature_selection import chi2, SelectKBest
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import recall_score

## Defining my features and my target
X = df[year_3].drop(['categories', 'compilation_3'], axis = 1)
y = df['categories']

# Instantiate
kbest = SelectKBest(k=20)
kbest.fit(X,y)
# Show the feature importance for Kbest of 20
kbest_importance = pd.DataFrame(zip(X.columns, kbest.get_support()), columns = ['feature', 'important?'])

kbest_features = kbest_importance[kbest_importance['important?'] == True].feature

## creating a dataframe of just the best features from year 3 here
year_3_best = df[kbest_features]
rooks_year_3_best = rooks_df[kbest_features]

# %%
## I now want to combine my PCA feature columns with my year 3 data to model
data = pca_df.join(year_3_best)
rooks_data = rookspca_df.join(rooks_year_3_best)
## defining my x and y again to perform select k best a second time
X = data
y = df['categories']


## I want to pick the 30 best features from the first select k best and pca cols
kbest_2 = SelectKBest(k = 30)
kbest_2.fit(X, y)

# Show the feature importance for Kbest of 30
kbest_2_importance = pd.DataFrame(zip(X.columns, kbest_2.get_support()), columns = ['feature', 'important?'])

kbest_2_features = kbest_2_importance[kbest_2_importance['important?'] == True].feature

## this dataframe is the best pca and year3 features together
year_3_refined = data[kbest_2_features]
rooks_year_3_refined = rooks_data[kbest_2_features]

print year_3_refined.shape
print rooks_year_3_refined.shape
rooks_year_3_refined.head()
# Out:
# (872, 30)
# (44, 30)
#                           pca_1     pca_2     pca_5     pca_6     pca_9  \
# Aaron Dobson           3.343230  3.234599 -4.016023 -0.169113 -1.153439
# Ace Sanders            2.086004  0.403029 -2.963584  0.108360  0.544618
# Ben Watson            -3.366994  5.500858  4.748690 -1.464372 -2.096872
# Chris Hogan            2.218197 -3.002587  3.537569 -1.209184 -0.536139
# Cordarrelle Patterson  8.507742  2.421352 -0.554181 -0.596962 -3.603206
#
#                          pca_11    pca_16    pca_18    pca_23    pca_24  \
# Aaron Dobson          -1.746534  1.394733  0.205744  0.494690  2.316730
# Ace Sanders           -2.491229 -0.844651  0.204843  1.559471  0.755661
# Ben Watson            -0.827829  0.089196 -0.481466 -0.541687 -0.305282
# Chris Hogan           -0.402435 -0.075203  0.091943  0.053656  1.088257
# Cordarrelle Patterson  2.432726  4.520804 -1.594856  1.775323 -1.143569
#
#                           ...      start_ratio_2  pct_team_tgts_2  \
# Aaron Dobson              ...             0.3750         0.028886
# Ace Sanders               ...             0.0000         0.000000
# Ben Watson                ...             0.0000         0.000000
# Chris Hogan               ...             0.2500         0.126882
# Cordarrelle Patterson     ...             0.0625         0.004184
#
#                        pct_team_receptions_2  pct_of_team_passyards_2  \
# Aaron Dobson                        0.028322                 0.027215
# Ace Sanders                         0.000000                 0.000000
# Ben Watson                          0.000000                 0.000000
# Chris Hogan                         0.122034                 0.134610
# Cordarrelle Patterson               0.006431                 0.003275
#
#                        pct_team_touchdowns_2   dropK_2     yacK_2  \
# Aaron Dobson                        0.000000  0.693147  10.241135
# Ace Sanders                         0.000000  0.000000   0.000000
# Ben Watson                          0.000000  0.000000   0.000000
# Chris Hogan                         0.086957  1.609438  26.402222
# Cordarrelle Patterson               0.000000  0.000000   0.900000
#
#                        td_points_2  compilation_2  avg_starts
# Aaron Dobson              0.000000       0.966747    0.458333
# Ace Sanders               0.000000       0.000000    0.088889
# Ben Watson                0.000000       0.000000    0.155556
# Chris Hogan               0.094066      10.623025    0.125000
# Cordarrelle Patterson     0.000000       0.063590    0.291667
#
# [5 rows x 30 columns]

# %%
print year_3_refined.columns
# Out:
# Index([u'pca_1', u'pca_2', u'pca_5', u'pca_6', u'pca_9', u'pca_11', u'pca_16',
#        u'pca_18', u'pca_23', u'pca_24', u'targets_2', u'receptions_2',
#        u'rec_yards_2', u'rec_tds_2', u'rec_ypg_2', u'100yd_gms_2',
#        u'first_down_ctchs_2', u'long_ctch_2', u'drops_2', u'DYAR_2',
#        u'start_ratio_2', u'pct_team_tgts_2', u'pct_team_receptions_2',
#        u'pct_of_team_passyards_2', u'pct_team_touchdowns_2', u'dropK_2',
#        u'yacK_2', u'td_points_2', u'compilation_2', u'avg_starts'],
#       dtype='object')

# %% [markdown]
# # Model Construction

# %% [markdown]
# ### SVC

# %%
## I want to build an SVC model to grid search through based on my data df
from sklearn.svm import SVC
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.cross_validation import cross_val_predict


## Defining my features and my target
X = year_3_refined
y = df['categories']

# assign some category weights to try out
cat_weights = {'all_pro':3, 'below average' : .6, 'league_average' : 2,
                  'quality starter' : 5}

## Instantiating an empty SVC along with some others trying to tune params
svc = SVC()

c_svc = SVC(C = .7, class_weight = cat_weights,
              kernel = 'linear')

kernel_svc = SVC(kernel = 'poly', class_weight = 'balanced', degree = 3)

# %%
cvp = cross_val_predict(c_svc, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, cvp)
# Out:
#              precision    recall  f1-score   support
#
#     all_pro       0.19      0.26      0.22        27
# below average       0.95      0.89      0.92       741
# league_average       0.30      0.40      0.34        57
# quality starter       0.25      0.32      0.28        47
#
# avg / total       0.84      0.81      0.83       872
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:   35.9s finished

# %%
cvp = cross_val_predict(kernel_svc, X, y, cv = 4, n_jobs = -1, verbose = 1)
print classification_report(y, cvp)
# Out:
#              precision    recall  f1-score   support
#
#     all_pro       0.16      0.30      0.21        27
# below average       0.93      0.92      0.92       741
# league_average       0.30      0.32      0.31        57
# quality starter       0.25      0.15      0.19        47
#
# avg / total       0.83      0.82      0.82       872
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.7min finished

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn_params = dict(n_neighbors=range(1, 100), weights = ['distance', 'uniform'],
                 algorithm=['ball_tree', 'kd_tree', 'auto'])

knn_grid = GridSearchCV(knn, param_grid = knn_params, cv = 4,
                        scoring = 'recall_macro', n_jobs = -1, verbose = 1)
knn_fit = knn_grid.fit(X, y)

print knn_fit.best_score_
print
print knn_fit.best_estimator_
print
print knn_fit.best_params_

knn_ideal = knn_fit.best_estimator_

cvp_pred = cross_val_predict(knn_ideal, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, cvp_pred)
# Out:
# Fitting 4 folds for each of 594 candidates, totalling 2376 fits
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 1848 tasks      | elapsed:    9.8s
# 0.399123570354
#
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
#
# {'n_neighbors': 5, 'weights': 'distance', 'algorithm': 'ball_tree'}
# [Parallel(n_jobs=-1)]: Done 2376 out of 2376 | elapsed:   12.2s finished
#              precision    recall  f1-score   support
#
#     all_pro       0.33      0.19      0.24        27
# below average       0.90      0.96      0.93       741
# league_average       0.23      0.12      0.16        57
# quality starter       0.42      0.32      0.36        47
#
# avg / total       0.81      0.85      0.83       872
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.1s finished

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import MinMaxScaler

mnb = MultinomialNB()

X = MinMaxScaler(feature_range = (1, 6)).fit_transform(year_3_refined)
y = df['categories']

nb_params = dict(alpha=[.001, .005, .008, .01, .015, .02, .03, .04, .05, .1, .15, .2, .4, .6, .8, 1., 1.2, 1.4, 1.6])

nb_grid = GridSearchCV(mnb, param_grid = nb_params, cv = 4,
                      scoring = 'recall_macro', n_jobs = -1, verbose = 1)

nb_fit = nb_grid.fit(X, y)

print nb_fit.best_score_
print
print nb_fit.best_estimator_
print
print nb_fit.best_params_

nb_ideal = nb_fit.best_estimator_

nb_pred = cross_val_predict(nb_ideal, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, nb_pred)
# Out:
# Fitting 4 folds for each of 19 candidates, totalling 76 fits
# 0.467875274586
#
# MultinomialNB(alpha=0.001, class_prior=None, fit_prior=True)
#
# {'alpha': 0.001}
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
#              precision    recall  f1-score   support
#
#     all_pro       0.50      0.07      0.13        27
# below average       0.95      0.90      0.92       741
# league_average       0.27      0.42      0.33        57
# quality starter       0.30      0.47      0.37        47
#
# avg / total       0.85      0.82      0.83       872

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

cat_weights = {'all_pro':3, 'below average' : .6, 'league_average' : 2,
                  'quality starter' : 5}

lr_params = dict(penalty = ['l2'], C=[.1, .3, .5,.7,.9, 1., 1.1,1.3,1.5],
                class_weight = ['balanced'],
                solver = ['newton-cg', 'lbfgs'])
                 

lr_grid = GridSearchCV(lr, param_grid = lr_params, cv = 4, n_jobs = -1, verbose = 1)
lr_fit = lr_grid.fit(X, y)

print lr_fit.best_score_
print
print lr_fit.best_estimator_
print
print lr_fit.best_params_

lr_ideal = lr_fit.best_estimator_
lr_pred = cross_val_predict(lr_ideal, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, lr_pred)
# Out:
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# 0.792431192661
#
# LogisticRegression(C=0.3, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='newton-cg', tol=0.0001, verbose=0, warm_start=False)
#
# {'penalty': 'l2', 'C': 0.3, 'solver': 'newton-cg', 'class_weight': 'balanced'}
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:    2.4s finished
#              precision    recall  f1-score   support
#
#     all_pro       0.26      0.41      0.32        27
# below average       0.97      0.86      0.91       741
# league_average       0.24      0.49      0.32        57
# quality starter       0.27      0.34      0.30        47
#
# avg / total       0.86      0.79      0.82       872
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.2s finished

# %%
allpro_weights = {'all_pro':4, 'below average' : .5, 'league_average' : .8,
                  'quality starter' : .8}

lr_ap = LogisticRegression(C = .5, class_weight = 'balanced', multi_class = 'ovr', penalty = 'l2',
                          solver = 'lbfgs')

allpro_pred = cross_val_predict(lr_ap, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, allpro_pred)
# Out:
#              precision    recall  f1-score   support
#
#     all_pro       0.23      0.37      0.28        27
# below average       0.97      0.85      0.91       741
# league_average       0.26      0.54      0.35        57
# quality starter       0.28      0.34      0.30        47
#
# avg / total       0.87      0.79      0.82       872
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.1s finished

# %%
y = df['categories'].map({'below average':0, 'league_average':1,
                          'quality starter':2, 'all_pro':3})
y.dtypes
# Out:
# dtype('int64')

# %%
from sklearn.ensemble import VotingClassifier

X = MinMaxScaler(feature_range = (1, 6)).fit_transform(year_3_refined)
y = df['categories'].map({'below average':0, 'league_average':1,
                          'quality starter':2, 'all_pro':3})

voter_weights = [2, 3, 2, 2]

voter = VotingClassifier(estimators =[
                        ('knn', knn_ideal),
                        ('nb', nb_ideal),
                        ('lr1', lr_ideal),
                        ('lr2', lr_ap)],
                        voting = 'soft',
                        weights = voter_weights)

voter_fit = voter.fit(X, y)

voter_cvp = cross_val_predict(voter_fit, X, y, cv = 4, n_jobs = -1, verbose = 1)
# Out:
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.3s finished

# %%
print classification_report(y, voter_cvp)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.91      0.93       741
#           1       0.29      0.47      0.36        57
#           2       0.29      0.32      0.31        47
#           3       0.33      0.19      0.24        27
#
# avg / total       0.85      0.83      0.84       872

# %%
print recall_score(y, voter_cvp, average = 'macro')
# Out:
# 0.472574758409

# %%
from sklearn.metrics import precision_score

print precision_score(y, voter_cvp, average = 'macro')
# Out:
# 0.466926988187

# %%
probs = voter_fit.predict_proba(X)

# %%
prob_df = pd.DataFrame(probs, index = year_3_refined.index, columns = ['below_avg', 'league_avg', 'qs', 'ap'])

# %%
prob_df.sort('below_avg', ascending=False)
# Out:
# /Users/TerryONeill/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                   below_avg  league_avg        qs        ap
# name
# Jammal Brown       0.971656    0.014233  0.012952  0.001160
# Atnaf Harris       0.966146    0.020818  0.010589  0.002447
# Paul Hubbard       0.965614    0.021547  0.010888  0.001951
# Isaac Jones        0.964599    0.025836  0.006054  0.003511
# Eddie Drummond     0.964080    0.002242  0.023284  0.010394
# Trindon Holliday   0.961520    0.013691  0.016723  0.008067
# Martin Nance       0.961088    0.023511  0.012903  0.002498
# Logan Payne        0.960436    0.021805  0.014654  0.003105
# Chad Owens         0.960129    0.017670  0.013376  0.008825
# Bert Emanuel       0.959813    0.015132  0.018338  0.006718
# Derrick Townsel    0.959406    0.015059  0.016064  0.009470
# Rich Parson        0.959350    0.015862  0.018782  0.006006
# Shelley Smith      0.959066    0.021700  0.016324  0.002910
# Airese Currie      0.958795    0.016207  0.018406  0.006592
# Jamaica Rector     0.958619    0.016696  0.018020  0.006665
# Darnell Jenkins    0.958591    0.016060  0.019726  0.005623
# Cord Parks         0.958542    0.015884  0.017624  0.007950
# Sam Giguere        0.958367    0.018077  0.018098  0.005457
# Damon Dunn         0.958333    0.017842  0.018013  0.005811
# P.J. Fleck         0.958330    0.017426  0.018566  0.005679
# Juaquin Iglesias   0.958144    0.016988  0.017309  0.007559
# Jeremy Ross        0.957671    0.016825  0.019011  0.006492
# Victor Riley       0.957609    0.028825  0.012767  0.000799
# Anwar Phillips     0.957564    0.016521  0.020367  0.005549
# Albert Johnson     0.957494    0.016910  0.019595  0.006001
# David Douglas      0.957474    0.017200  0.018213  0.007114
# Onrea Jones        0.957445    0.016624  0.021029  0.004902
# Jason Carter       0.957445    0.017429  0.019295  0.005830
# Sean Ryan          0.957385    0.024439  0.015518  0.002658
# LaShaun Ward       0.957331    0.017090  0.019266  0.006313
# ...                     ...         ...       ...       ...
# Marques Colston    0.003466    0.248986  0.512712  0.234836
# Andre Johnson      0.003265    0.055413  0.622820  0.318502
# Darrell Jackson    0.003014    0.066169  0.400041  0.530775
# Demaryius Thomas   0.002626    0.137698  0.593476  0.266199
# Randy Moss         0.002341    0.039824  0.351407  0.606428
# Chris Chambers     0.002278    0.264759  0.249511  0.483452
# Larry Fitzgerald   0.002216    0.169539  0.303123  0.525122
# Anquan Boldin      0.002148    0.060295  0.378883  0.558674
# Keenan McCardell   0.002111    0.421909  0.298164  0.277815
# Greg Jennings      0.002106    0.177706  0.547186  0.273002
# Brandon LaFell     0.002053    0.502833  0.301132  0.193983
# Torry Holt         0.001954    0.205369  0.518851  0.273826
# DeSean Jackson     0.001933    0.257695  0.503723  0.236649
# Hakeem Nicks       0.001796    0.436864  0.302913  0.258427
# Julio Jones        0.001720    0.291943  0.258147  0.448191
# Joe Horn           0.001275    0.131116  0.327001  0.540608
# Hines Ward         0.001235    0.114279  0.332646  0.551840
# T.Y. Hilton        0.001124    0.214903  0.530248  0.253726
# Terrell Owens      0.001011    0.014811  0.352975  0.631202
# Troy Brown         0.000994    0.229516  0.518335  0.251155
# Laveranues Coles   0.000899    0.231447  0.282729  0.484925
# Lee Evans          0.000747    0.155467  0.576284  0.267502
# Marvin Harrison    0.000655    0.009003  0.339564  0.650777
# Chad Johnson       0.000603    0.214105  0.272142  0.513150
# A.J. Green         0.000518    0.147817  0.502179  0.349486
# Alshon Jeffery     0.000472    0.189426  0.525804  0.284298
# David Boston       0.000382    0.378323  0.308734  0.312560
# Mike Wallace       0.000269    0.414681  0.309615  0.275435
# Percy Harvin       0.000233    0.168138  0.544879  0.286750
# Rod Smith          0.000123    0.040175  0.599485  0.360217
#
# [872 rows x 4 columns]

# %% [markdown]
# # 2016 Player Predictions

# %%
rooks_preds = voter_fit.predict(rooks_year_3_refined)
rooks_preds_proba = voter_fit.predict_proba(rooks_year_3_refined)
rooks_preds_df = pd.DataFrame(rooks_preds, index = rooks_year_3_refined.index,
                            columns = ['Prediction'])
rooks_preds_df['Prediction'] = rooks_preds_df['Prediction'].map(
                                {0:'Below Average',
                                 1:'League Average',
                                 2:'Quality Starter',
                                 3:'All Pro'})
rooks_preds_proba = pd.DataFrame(rooks_preds_proba, index = rooks_year_3_refined.index,
                                columns = ['below_avg', 'league_avg', 'qual_start', 'all_pro'])

rooks_preds_df = rooks_preds_df.join(rooks_preds_proba)
rooks_preds_df.sort_values('all_pro', ascending = False)
# Out:
#                             Prediction  below_avg    league_avg  qual_start  \
# DeAndre Hopkins                All Pro   0.333333  4.445714e-02    0.199987
# Terrance Williams              All Pro   0.333333  4.446293e-02    0.201045
# Robert Woods                   All Pro   0.333333  4.447612e-02    0.201740
# Markus Wheaton                 All Pro   0.333333  4.446737e-02    0.202962
# Chris Hogan                    All Pro   0.333333  4.448237e-02    0.224719
# Kenny Stills                   All Pro   0.333333  4.447801e-02    0.255606
# Justin Hunter            Below Average   0.377751  4.450994e-02    0.232890
# Marquess Wilson          Below Average   0.333333  4.447180e-02    0.301713
# Jaron Brown              Below Average   0.390091  5.563994e-02    0.318730
# Denard Robinson        Quality Starter   0.081127  2.100872e-11    0.700305
# Aaron Dobson             Below Average   0.377771  4.484076e-02    0.366361
# Quinton Patton         Quality Starter   0.333333  4.445996e-02    0.416749
# Stedman Bailey         Quality Starter   0.377768  5.348708e-02    0.377918
# Cordarrelle Patterson   League Average   0.222441  3.271119e-01    0.264117
# Kenbrell Thompkins     Quality Starter   0.377746  4.472866e-02    0.407558
# Tavon Austin           Quality Starter   0.111555  4.443229e-02    0.702375
# Marquise Goodwin       Quality Starter   0.258815  2.272465e-01    0.378651
# Myles White              Below Average   0.533365  1.202911e-01    0.211496
# Russell Shepard          Below Average   0.521998  2.916366e-01    0.086629
# DeVier Posey             Below Average   0.344247  2.426266e-01    0.314622
# Ace Sanders              Below Average   0.495525  1.508248e-01    0.308843
# Dion Sims                Below Average   0.534993  2.223513e-01    0.226986
# Eric Page                Below Average   0.737645  2.987426e-02    0.227053
# Patrick Edwards          Below Average   0.745309  2.972951e-02    0.219576
# Skye Dawson              Below Average   0.759763  1.884939e-02    0.216933
# Michael Campbell         Below Average   0.817265  1.905270e-02    0.159380
# Darius Johnson           Below Average   0.741794  2.763470e-02    0.226711
# Julian Talley            Below Average   0.846681  1.962476e-02    0.130344
# Tim Wright               Below Average   0.751495  4.650599e-03    0.240889
# Justin Veltung           Below Average   0.844773  1.550545e-02    0.136925
# Dominique Davis          Below Average   0.824776  1.552575e-02    0.157943
# Rodney Smith             Below Average   0.820633  1.349858e-02    0.164268
# Lamaar Thomas            Below Average   0.775051  1.768731e-02    0.205947
# Tori Gurley              Below Average   0.773502  1.696707e-02    0.208568
# Greg Jenkins             Below Average   0.882557  1.141232e-01    0.002407
# Jimmy Graham             Below Average   0.611555  8.670304e-05    0.387477
# Da'Rick Rogers           Below Average   0.770678  1.029562e-02    0.218199
# Teddy Williams           Below Average   0.753246  3.818054e-02    0.207872
# Michael Egnew            Below Average   0.769742  1.903609e-02    0.210552
# Josh Boyce               Below Average   0.767686  2.399701e-02    0.207763
# Kellen Davis             Below Average   0.767338  1.688395e-02    0.215304
# Ben Watson               Below Average   0.773137  6.316958e-03    0.220238
# Erik Lorig               Below Average   0.773241  1.595477e-02    0.210501
# David Johnson            Below Average   0.775721  1.466707e-02    0.209503
#
#                         all_pro
# DeAndre Hopkins        0.422222
# Terrance Williams      0.421159
# Robert Woods           0.420450
# Markus Wheaton         0.419238
# Chris Hogan            0.397465
# Kenny Stills           0.366583
# Justin Hunter          0.344849
# Marquess Wilson        0.320482
# Jaron Brown            0.235539
# Denard Robinson        0.218568
# Aaron Dobson           0.211027
# Quinton Patton         0.205458
# Stedman Bailey         0.190827
# Cordarrelle Patterson  0.186330
# Kenbrell Thompkins     0.169967
# Tavon Austin           0.141638
# Marquise Goodwin       0.135288
# Myles White            0.134848
# Russell Shepard        0.099736
# DeVier Posey           0.098505
# Ace Sanders            0.044807
# Dion Sims              0.015669
# Eric Page              0.005428
# Patrick Edwards        0.005386
# Skye Dawson            0.004455
# Michael Campbell       0.004303
# Darius Johnson         0.003860
# Julian Talley          0.003350
# Tim Wright             0.002965
# Justin Veltung         0.002797
# Dominique Davis        0.001755
# Rodney Smith           0.001601
# Lamaar Thomas          0.001315
# Tori Gurley            0.000963
# Greg Jenkins           0.000913
# Jimmy Graham           0.000882
# Da'Rick Rogers         0.000828
# Teddy Williams         0.000701
# Michael Egnew          0.000669
# Josh Boyce             0.000553
# Kellen Davis           0.000474
# Ben Watson             0.000307
# Erik Lorig             0.000303
# David Johnson          0.000109
