# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Our Data

# %%
## I will first be importing my pivoted catcherr csv in order to add the
## features needed to save the final csv
df = pd.read_csv('https://raw.githubusercontent.com/oneilltp18/GABBERT/master/wide_receivers/pivot_catcherr.csv')

## Now I am importing the pivoted csv of just the people who were rookies in
## 2013, this is our overall validation set that we are predicting
rooks_df = pd.read_csv('https://raw.githubusercontent.com/oneilltp18/GABBERT/master/wide_receivers/rooks_df.csv')

#######
####### All the below code has been commented out since it was only necessary the first time through, as
####### the csv has been saved over

# #need to drop the unnamed first column when we import csv's
# df.drop('Unnamed: 0', axis = 1, inplace = True)

# going to set the index to the name of the player
df.set_index(df.name, inplace = True)


# need to drop the name column as it is now the index
df.drop('name', axis = 1, inplace = True)


# ## I also need to drop a couple year 4 stats that snuck in for some reason
# df.drop(['receptions_3', 'rec_yards_3'], axis = 1, inplace = True)

# # Also I will create categories for player season_3 ratings (bins)
# bins = [-1, 10, 30, 65, 200]
# labels = ['below average', 'league_average', 'quality starter', 'all_pro']
# df['categories'] =  pd.cut(df['compilation_3'], bins, labels=labels)


# ###### I am now rewriting over the pivot_catcherr csv with our final version
# df.to_csv('/Users/TerryONeill/Terry_git/Capstone/GABBERT/wide_receivers/pivot_catcherr.csv')

df.head()
# Out:
#                  season_0  season_1  season_2  age_0  age_1  age_2  weight_0  \
# name
# A.J. Green         2011.0    2012.0    2013.0   23.0   24.0   25.0     205.0
# A.J. Jenkins       2012.0    2013.0    2014.0   23.0   24.0   25.0     192.0
# Aaron Brown        2009.0    2010.0    2011.0   24.0   25.0   26.0     196.0
# Aaron Halterman    2007.0    2008.0    2009.0   25.0   26.0   27.0     255.0
# Aaron Moorehead    2003.0    2004.0    2005.0   23.0   24.0   25.0     200.0
#
#                  weight_1  weight_2  bmi_0       ...         compilation_0  \
# name                                             ...
# A.J. Green          205.0     205.0   25.0       ...             53.006410
# A.J. Jenkins        192.0     192.0   26.0       ...              0.000000
# Aaron Brown         196.0     196.0   26.6       ...              1.007213
# Aaron Halterman     255.0     255.0   30.2       ...              0.030196
# ...

# %%
## I need to set the index and drop the name col for the rookies as well
# rooks_df.set_index(rooks_df['name'], inplace = True)
# rooks_df.head()

rooks_df.index = rooks_df.name.values
rooks_df.head()
# Out:
#                                         name  season_0  season_1  season_2  \
# Aaron Dobson                    Aaron Dobson    2013.0    2014.0    2015.0
# Ace Sanders                      Ace Sanders    2013.0    2014.0    2015.0
# Ben Watson                        Ben Watson    2013.0    2014.0    2015.0
# Chris Hogan                      Chris Hogan    2013.0    2014.0    2015.0
# Cordarrelle Patterson  Cordarrelle Patterson    2013.0    2014.0    2015.0
#
#                        age_0  age_1  age_2  weight_0  weight_1  weight_2  \
# Aaron Dobson            22.0   23.0   24.0     210.0     210.0     210.0
# Ace Sanders             22.0   23.0   24.0     173.0     173.0     173.0
# Ben Watson              33.0   34.0   35.0     255.0     255.0     255.0
# Chris Hogan             25.0   26.0   27.0     220.0     220.0     220.0
# Cordarrelle Patterson   22.0   23.0   24.0     216.0     216.0     216.0
#
# ...

# %%
rooks_df.drop('name', axis = 1, inplace = True)
rooks_df.head()
# Out:
#                        season_0  season_1  season_2  age_0  age_1  age_2  \
# Aaron Dobson             2013.0    2014.0    2015.0   22.0   23.0   24.0
# Ace Sanders              2013.0    2014.0    2015.0   22.0   23.0   24.0
# Ben Watson               2013.0    2014.0    2015.0   33.0   34.0   35.0
# Chris Hogan              2013.0    2014.0    2015.0   25.0   26.0   27.0
# Cordarrelle Patterson    2013.0    2014.0    2015.0   22.0   23.0   24.0
#
#                        weight_0  weight_1  weight_2  bmi_0      ...        \
# Aaron Dobson              210.0     210.0     210.0   26.2      ...
# Ace Sanders               173.0     173.0     173.0   27.1      ...
# Ben Watson                255.0     255.0     255.0   31.9      ...
# Chris Hogan               220.0     220.0     220.0   29.0      ...
# Cordarrelle Patterson     216.0     216.0     216.0   27.7      ...
#
#                        td_points_1  td_points_2  compilation_0  compilation_1  \
# ...

# %%
## I want to create a list of the column names associated with a players
## first and second year stats, the following loop will go through and add
## all these stats to the list year_12

year_12 = []
for col in df:
    if col == 'year_1_growth':
        pass
    else:
        if '_0' in col:
            year_12.append(col)
        if '_1' in col:
            year_12.append(col)
            
            
## I also want to create a list of the rest of the col names (year3 data)
year_3 = []
for col in df:
    if col not in year_12:
        year_3.append(col)
        
year_3
# Out:
# ['season_2',
#  'age_2',
#  'weight_2',
#  'bmi_2',
#  'games_2',
#  'rush_atts_2',
#  'rush_yds_2',
#  'rush_y/a_2',
#  'rush_tds_2',
#  'rush_ypg_2',
#  'targets_2',
#  'receptions_2',
#  'rec_yards_2',
#  'yards/reception_2',
#  'rec_tds_2',
#  'rec_ypg_2',
#  'ctch_pct_2',
#  'y/tgt_2',
#  'fumbles_2',
#  'fumbles_recovered_2',
#  'fum_ret_yds_2',
#  'fum_tds_2',
#  'forced_fumbles_2',
#  'pro_bowls_2',
#  'all_pros_2',
#  '100yd_gms_2',
#  'first_down_ctchs_2',
#  'first_down_ctchpct_2',
#  'long_ctch_2',
#  'drops_2',
#  'EYds_2',
#  'DVOA_2',
#  'DYAR_2',
#  '40 Yard_2',
#  'rookie_age_2',
#  'rookie_season_2',
#  'height_inches_2',
#  'start_ratio_2',
#  'dpis_drawn_2',
#  'dpi_yards_2',
#  'pct_team_tgts_2',
#  'pct_team_receptions_2',
#  'pct_of_team_passyards_2',
#  'pct_team_touchdowns_2',
#  'dropK_2',
#  'yacK_2',
#  'td_points_2',
#  'compilation_2',
#  'compilation_3',
#  'avg_starts',
#  'dpis',
#  'dpi_yards',
#  'year_1_growth',
#  'year_2_growth',
# ...

# %%
## I am going to repeat this process for the rookie data as well
rooksyear_12 = []
for col in rooks_df:
    if col == 'year_1_growth':
        pass
    else:
        if '_0' in col:
            rooksyear_12.append(col)
        if '_1' in col:
            rooksyear_12.append(col)
            
            
## I also want to create a list of the rest of the col names (year3 data)
rooksyear_3 = []
for col in rooks_df:
    if col not in rooksyear_12:
        rooksyear_3.append(col)
        
rooksyear_3
# Out:
# ['season_2',
#  'age_2',
#  'weight_2',
#  'bmi_2',
#  'games_2',
#  'rush_atts_2',
#  'rush_yds_2',
#  'rush_y/a_2',
#  'rush_tds_2',
#  'rush_ypg_2',
#  'targets_2',
#  'receptions_2',
#  'rec_yards_2',
#  'yards/reception_2',
#  'rec_tds_2',
#  'rec_ypg_2',
#  'ctch_pct_2',
#  'y/tgt_2',
#  'fumbles_2',
#  'fumbles_recovered_2',
#  'fum_ret_yds_2',
#  'fum_tds_2',
#  'forced_fumbles_2',
#  'pro_bowls_2',
#  'all_pros_2',
#  '100yd_gms_2',
#  'first_down_ctchs_2',
#  'first_down_ctchpct_2',
#  'long_ctch_2',
#  'drops_2',
#  'EYds_2',
#  'DVOA_2',
#  'DYAR_2',
#  '40 Yard_2',
#  'rookie_age_2',
#  'rookie_season_2',
#  'height_inches_2',
#  'start_ratio_2',
#  'dpis_drawn_2',
#  'dpi_yards_2',
#  'pct_team_tgts_2',
#  'pct_team_receptions_2',
#  'pct_of_team_passyards_2',
#  'pct_team_touchdowns_2',
#  'dropK_2',
#  'yacK_2',
#  'td_points_2',
#  'compilation_2',
#  'avg_starts',
#  'dpis',
#  'dpi_yards',
#  'year_1_growth',
#  'year_2_growth']

# %%
## I want to see how many players in our dataframe played for zero games in their second season
## I want to filter these players out, as this means they dropped out of the league
print df.games_1.value_counts()
# Out:
# 0.0     380
# 16.0    196
# 15.0     40
# 14.0     38
# 13.0     30
# 12.0     23
# 11.0     23
# 2.0      21
# 1.0      20
# 9.0      18
# 10.0     15
# 7.0      15
# 8.0      13
# 6.0      12
# 5.0      10
# 4.0      10
# 3.0       7
# 9.5       1
# Name: games_1, dtype: int64

# %%
## Here I am creating a dataframe that doesnt include any players that dropped out of the NFL in their second year

no_dropouts = df[(df.games_1 != 0) & (df.games_2 != 0)]

# %% [markdown]
# I am now going to conduct PCA on the first 2 seasons of data in order to reduce dimensionality and to extract the signal from these features that seem to have colinearity.
#
# I am going to work off of the dataframe titled "**no_dropouts**" so that we are not including players that dropped out of the NFL in their second year.

# %% [markdown]
# # PCA

# %%
## I now want to perform PCA on all the year 1 and 2 stats columns
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# I am creating a dataframe of the scaled values of the year 1 and 2 columns
pca_df = scale(no_dropouts[year_12])

# doing the same thing for the rookie data
rookspca_df = scale(rooks_df[rooksyear_12])

# %%
## creating the covariance matrix - this explains the variance between the different
## features within our dataframe

## for example, the value in the i,j position within the matrix explains the variance
## between the ith and the jth elements of a random vector, or between our features
cov_mat = np.cov(pca_df.T)

## creating my eigenvalues and corresponding eigenvectors
eigenValues, eigenVectors = np.linalg.eig(cov_mat)

## creating the eigenpairs - just pairing the eigenvalue with its eigenvector
eigenPairs = [(np.abs(eigenValues[i]), eigenVectors[:,i]) for i in range(len(eigenValues))]

# %%
## loop through the eigenpairs and printing out the first row (eigenvalue)
## this is also seen in the code block above but just wanted to loop through again
## as it is a bit more clear like this
## I am also creating a list of the eigenvalues in ascending order to be able to reference it
sort_values = []
for i in eigenPairs:
    print i[0]
    sort_values.append(i[0])
# Out:
# 29.5040401466
# 7.39073737632
# 5.9615313342
# 5.15432807043
# 4.03478108521
# 3.01522857588
# 2.82168482826
# 2.62134060341
# 2.51631700184
# 2.23988077771
# 2.17235931456
# 1.76895359748
# 1.59611060168
# 1.5303405117
# 1.37222640546
# 1.2821643993
# 1.21022409336
# 1.05806186472
# 1.01807287939
# 1.02906566108
# 0.948477049936
# 0.910480004044
# 0.902714563847
# 0.83634951333
# 0.806537558735
# 0.77926857137
# 0.750720261079
# 0.700497218577
# 0.676719030108
# 0.654543512281
# 0.603350779044
# 0.565179189523
# 0.496453035282
# 0.489216461613
# 0.477402630873
# 0.466215307259
# 0.431637913397
# 0.413977969192
# 0.399186725124
# 0.391354613699
# 0.357440103749
# 0.322662294207
# 0.300262717479
# 0.294403530645
# 0.263660939676
# 0.220034665383
# 0.241684406952
# 0.234475963384
# 0.187846934868
# 0.175361596373
# 0.161796030163
# 0.155953350595
# 0.152883580078
# 0.124080053681
# 0.117003249076
# 0.114184424435
# 0.0908417573358
# 0.0766562669381
# 0.0726516727942
# 0.0634354498166
# ...

# %%
## we have the eigenvalues above showing us feature correlation explanation, but it helps
## to see the cumulative variance explained as well, which i can show below

## need to sum the eigen values to get percentages
sumEigenvalues = sum(eigenValues)

## this is a percentage explanation
variance_explained = [(i/sumEigenvalues)*100 for i in sort_values]
variance_explained
# Out:
# [(30.640525076714482+0j),
#  (7.6754259006315859+0j),
#  (6.1911673599170065+0j),
#  (5.3528709190659338+0j),
#  (4.1901993898561969+0j),
#  (3.1313740874843199+0j),
#  (2.9303751048723252+0j),
#  (2.7223136931144527+0j),
#  (2.6132446204918582+0j),
#  (2.3261601732239012+0j),
#  (2.2560378077926004+0j),
#  (1.837093048745905+0j),
#  (1.6575922034051296+0j),
#  (1.5892886734092362+0j),
#  (1.4250840691123188+0j),
#  (1.3315529071331318+0j),
#  (1.2568414866823439+0j),
#  (1.0988180241616758+0j),
#  (1.0572886776156043+0j),
#  (1.0687048972653657+0j),
#  (0.9850120420412487+0j),
#  (0.94555136371610793+0j),
#  (0.93748680157833375+0j),
#  (0.86856539337485439+0j),
#  (0.83760509309759124+0j),
#  (0.80928571422527518+0j),
#  (0.77963773337087738+0j),
#  (0.72748011748000008+0j),
#  (0.70278600181141904+0j),
#  (0.67975629107751112+0j),
#  (0.62659163231492465+0j),
#  (0.58694968700415551+0j),
#  (0.51557622621781329+0j),
#  (0.5080609023547491+0j),
#  (0.49579200713790167+0j),
# ...

# %%
### based on the above results, it seems that sticking to 25 features would be a decent
## cutoff point since the variance explained altogether falls under .8% for each feature

## this can very easily be manipulated by changing n_components adn then adding/subtracting
## columns to the dataframe in the code block below

## instantiate
pca = PCA(n_components = 26)

## fit and transform the standardized data
pca_model = pca.fit(pca_df)
pca_cols = pca_model.transform(pca_df)

## Here I am fitting the rookie data to the training PCA fit
rooks_pca_cols = pca_model.transform(rookspca_df)

# %%
## Here I am simply creating the column headers for the pca features
pca_col_list = []

for i in range(1, 27):
    pca_col_list.append('pca_'+str(i))
    
## going to organize the columns into dataframe for organization
## I am going to set the index of our pca dataframe to the names 
## of the related player
pca_df = pd.DataFrame(pca_cols, index = no_dropouts.index, columns = pca_col_list)
## doing the same for the rookie information
rookspca_df = pd.DataFrame(rooks_pca_cols, index = rooks_df.index, columns = pca_col_list)
##previewing dataframe
pca_df.head()
rookspca_df.head()
# Out:
#                           pca_1     pca_2     pca_3     pca_4     pca_5  \
# Aaron Dobson           3.401074 -2.978046  0.539500 -3.532242 -2.001862
# Ace Sanders            1.699434 -0.276348  2.734778 -0.251684 -1.466757
# Ben Watson            -1.865532 -4.787426 -1.430580  2.970102  0.554545
# Chris Hogan            1.919789  2.611535 -2.799204  3.634366  0.499403
# Cordarrelle Patterson  8.642995  1.121584  4.740460 -3.724479 -0.777130
#
#                           pca_6     pca_7     pca_8     pca_9    pca_10  \
# Aaron Dobson          -1.373677  0.436753  0.931185 -0.093731  0.358635
# Ace Sanders           -2.454167  0.914213  1.367186  2.773112  0.126120
# Ben Watson             3.929670  1.747933 -3.533034  3.407177 -2.940925
# Chris Hogan            0.009189 -1.045074 -0.723435  1.143078 -0.680336
# Cordarrelle Patterson  0.914489 -3.297354 -1.893098 -2.124726  3.236054
#
#                          ...       pca_17    pca_18    pca_19    pca_20  \
# ...

# %% [markdown]
# # Year 3 Stats Feature Selection

# %%
from sklearn.feature_selection import chi2, SelectKBest
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import recall_score

## Defining my features and my target
X = no_dropouts[year_3].drop(['categories', 'compilation_3'], axis = 1)
y = no_dropouts['categories']

# Instantiate
kbest = SelectKBest(k=20)
kbest.fit(X,y)
# Show the feature importance for Kbest of 20
kbest_importance = pd.DataFrame(zip(X.columns, kbest.get_support()), columns = ['feature', 'important?'])

kbest_features = kbest_importance[kbest_importance['important?'] == True].feature

## creating a dataframe of just the best features from year 3 here
year_3_best = no_dropouts[kbest_features]
rooks_year_3_best = rooks_df[kbest_features]

# %%
## I now want to combine my PCA feature columns with my year 3 data to model
data = pca_df.join(year_3_best)
rooks_data = rookspca_df.join(rooks_year_3_best)
## defining my x and y again to perform select k best a second time
X = data
y = no_dropouts['categories']


## I want to pick the 30 best features from the first select k best and pca cols
kbest_2 = SelectKBest(k = 30)
kbest_2.fit(X, y)

# Show the feature importance for Kbest of 30
kbest_2_importance = pd.DataFrame(zip(X.columns, kbest_2.get_support()), columns = ['feature', 'important?'])

kbest_2_features = kbest_2_importance[kbest_2_importance['important?'] == True].feature

## this dataframe is the best pca and year3 features together
year_3_refined = data[kbest_2_features]
rooks_year_3_refined = rooks_data[kbest_2_features]

print year_3_refined.shape
print rooks_year_3_refined.shape
rooks_year_3_refined.head()
# Out:
# (331, 30)
# (44, 30)
#                           pca_1     pca_2     pca_5     pca_8    pca_13  \
# Aaron Dobson           3.401074 -2.978046 -2.001862  0.931185  1.572226
# Ace Sanders            1.699434 -0.276348 -1.466757  1.367186 -0.588867
# Ben Watson            -1.865532 -4.787426  0.554545 -3.533034  0.219134
# Chris Hogan            1.919789  2.611535  0.499403 -0.723435 -0.410418
# Cordarrelle Patterson  8.642995  1.121584 -0.777130 -1.893098 -3.523463
#
#                          pca_16    pca_18    pca_19    pca_21    pca_26  \
# Aaron Dobson          -0.236207 -0.497792  1.851677  2.331846 -0.569555
# Ace Sanders            0.559339  0.555012 -1.626420  1.016042 -1.452775
# Ben Watson             0.818835  0.111036  0.155007 -0.424638  0.770140
# Chris Hogan            0.170342  0.331878  0.804793  0.028961 -0.076544
# Cordarrelle Patterson -0.484669  0.454442  0.385731 -0.111843  0.050906
#
#                           ...      start_ratio_2  pct_team_tgts_2  \
# ...

# %%
print year_3_refined.columns
# Out:
# Index([u'pca_1', u'pca_2', u'pca_5', u'pca_8', u'pca_13', u'pca_16', u'pca_18',
#        u'pca_19', u'pca_21', u'pca_26', u'targets_2', u'receptions_2',
#        u'rec_yards_2', u'rec_tds_2', u'rec_ypg_2', u'100yd_gms_2',
#        u'first_down_ctchs_2', u'long_ctch_2', u'drops_2', u'DYAR_2',
#        u'start_ratio_2', u'pct_team_tgts_2', u'pct_team_receptions_2',
#        u'pct_of_team_passyards_2', u'pct_team_touchdowns_2', u'dropK_2',
#        u'yacK_2', u'td_points_2', u'compilation_2', u'avg_starts'],
#       dtype='object')

# %% [markdown]
# # Model Construction

# %% [markdown]
# ### SVC

# %%
## I want to build an SVC model to grid search through based on my data df
from sklearn.svm import SVC
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.cross_validation import cross_val_predict


## Defining my features and my target
X = year_3_refined
y = no_dropouts['categories']

# assign some category weights to try out
cat_weights = {'all_pro':1, 'below average' : .3, 'league_average' : 5,
                  'quality starter' : 5}

## Instantiating an empty SVC along with some others trying to tune params
svc = SVC()

c_svc = SVC(C = .7, class_weight = 'balanced',
              kernel = 'linear', probability = True)

kernel_svc = SVC(kernel = 'poly', class_weight = cat_weights,
                 degree = 3, probability = True)

# %%
cvp = cross_val_predict(c_svc, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, cvp)
# Out:
#              precision    recall  f1-score   support
#
#     all_pro       0.19      0.35      0.24        23
# below average       0.84      0.73      0.78       220
# league_average       0.25      0.29      0.27        51
# quality starter       0.26      0.27      0.27        37
#
# avg / total       0.64      0.59      0.61       331
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.9min finished

# %%
cvp = cross_val_predict(kernel_svc, X, y, cv = 4, n_jobs = -1, verbose = 1)
print classification_report(y, cvp)

# %%
kernel_svcfit = kernel_svc.fit(X, y)

# %%
c_svcfit = c_svc.fit(X, y)

# %%
rooks_preds = c_svcfit.predict(rooks_year_3_refined)
rooks_preds_proba = c_svcfit.predict_proba(rooks_year_3_refined)
rooks_preds_df = pd.DataFrame(rooks_preds, index = rooks_year_3_refined.index,
                            columns = ['Prediction'])
# rooks_preds_df['Prediction'] = rooks_preds_df['Prediction'].map(
#                                 {0:'Below Average',
#                                  1:'League Average',
#                                  2:'Quality Starter',
#                                  3:'All Pro'})
rooks_preds_proba = pd.DataFrame(rooks_preds_proba, index = rooks_year_3_refined.index,
                                columns = ['all_pro', 'below_avg', 'league_avg', 'qual_starter'])

rooks_preds_df = rooks_preds_df.join(rooks_preds_proba)
print 'Number of Predictions for Each Class: \n', rooks_preds_df.Prediction.value_counts()
rooks_preds_df.sort_values('all_pro', ascending = False)
# Out:
# Number of Predictions for Each Class:
# below average      34
# quality starter     6
# league_average      2
# all_pro             2
# Name: Prediction, dtype: int64
#                             Prediction   all_pro  below_avg  league_avg  \
# Tavon Austin                   all_pro  0.194662   0.275392    0.319298
# DeAndre Hopkins                all_pro  0.193650   0.347272    0.377887
# Denard Robinson        quality starter  0.103160   0.546872    0.194753
# Terrance Williams       league_average  0.079287   0.547290    0.262465
# Robert Woods             below average  0.073237   0.639652    0.161372
# Markus Wheaton          league_average  0.070905   0.572803    0.246698
# Marquess Wilson        quality starter  0.066910   0.576960    0.169289
# Quinton Patton         quality starter  0.065996   0.612234    0.129790
# Jimmy Graham           quality starter  0.060432   0.574499    0.032279
# Chris Hogan              below average  0.057140   0.722655    0.145618
# ...

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn_params = dict(n_neighbors=range(1, 100), weights = ['distance', 'uniform'],
                 algorithm=['ball_tree', 'kd_tree', 'auto'],
                 p = [1, 2])

knn_grid = GridSearchCV(knn, param_grid = knn_params, cv = 4,
                        scoring = 'recall_macro', n_jobs = -1, verbose = 1)
knn_fit = knn_grid.fit(X, y)

print knn_fit.best_score_
print
print knn_fit.best_estimator_
print
print knn_fit.best_params_

knn_ideal = knn_fit.best_estimator_

cvp_pred = cross_val_predict(knn_ideal, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, cvp_pred)
# Out:
# Fitting 4 folds for each of 1188 candidates, totalling 4752 fits
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 3608 tasks      | elapsed:    8.6s
# 0.373754686066
#
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='distance')
#
# {'n_neighbors': 4, 'weights': 'distance', 'algorithm': 'ball_tree', 'p': 2}
# [Parallel(n_jobs=-1)]: Done 4752 out of 4752 | elapsed:   10.8s finished
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
#              precision    recall  f1-score   support
#
#           0       0.76      0.90      0.82       220
#           1       0.28      0.22      0.24        51
#           2       0.35      0.16      0.22        37
#           3       0.36      0.22      0.27        23
#
# avg / total       0.61      0.66      0.63       331

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import MinMaxScaler

mnb = MultinomialNB()

X = MinMaxScaler(feature_range = (1, 6)).fit_transform(year_3_refined)
y = no_dropouts['categories']

nb_params = dict(alpha=[.001, .005, .008, .01, .015, .02, .03, .04, .05, .1, .15, .2, .4, .6, .8, 1., 1.2, 1.4, 1.6])

nb_grid = GridSearchCV(mnb, param_grid = nb_params, cv = 4,
                      scoring = 'recall_macro', n_jobs = -1, verbose = 1)

nb_fit = nb_grid.fit(X, y)

print nb_fit.best_score_
print
print nb_fit.best_estimator_
print
print nb_fit.best_params_

nb_ideal = nb_fit.best_estimator_

nb_pred = cross_val_predict(nb_ideal, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, nb_pred)
# Out:
# Fitting 4 folds for each of 19 candidates, totalling 76 fits
# 0.428644215804
#
# MultinomialNB(alpha=0.001, class_prior=None, fit_prior=True)
#
# {'alpha': 0.001}
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
#              precision    recall  f1-score   support
#
#     all_pro       0.30      0.30      0.30        23
# below average       0.82      0.83      0.83       220
# league_average       0.30      0.27      0.29        51
# quality starter       0.28      0.30      0.29        37
#
# avg / total       0.65      0.65      0.65       331

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

cat_weights = {'all_pro':3, 'below average' : .6, 'league_average' : 2,
                  'quality starter' : 5}

lr_params = dict(penalty = ['l2'], C=[.1, .3, .5,.7,.9, 1., 1.1,1.3,1.5],
                class_weight = ['balanced'],
                solver = ['newton-cg', 'lbfgs'])
                 

lr_grid = GridSearchCV(lr, param_grid = lr_params, cv = 4, n_jobs = -1, verbose = 1,
                      scoring = 'precision_macro')
lr_fit = lr_grid.fit(X, y)

print lr_fit.best_score_
print
print lr_fit.best_estimator_
print
print lr_fit.best_params_

lr_ideal = lr_fit.best_estimator_
lr_pred = cross_val_predict(lr_ideal, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, lr_pred)
# Out:
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# 0.449698097322
#
# LogisticRegression(C=1.3, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='newton-cg', tol=0.0001, verbose=0, warm_start=False)
#
# {'penalty': 'l2', 'C': 1.3, 'solver': 'newton-cg', 'class_weight': 'balanced'}
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:    1.5s finished
#              precision    recall  f1-score   support
#
#     all_pro       0.23      0.35      0.28        23
# below average       0.90      0.77      0.83       220
# league_average       0.33      0.43      0.37        51
# quality starter       0.29      0.32      0.31        37
#
# avg / total       0.70      0.64      0.66       331
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.1s finished

# %%
allpro_weights = {'all_pro':4, 'below average' : .5, 'league_average' : 10,
                  'quality starter' : 2}

lr_ap = LogisticRegression(C = .5, class_weight = 'balanced', multi_class = 'multinomial', penalty = 'l2',
                          solver = 'newton-cg')

allpro_pred = cross_val_predict(lr_ap, X, y, cv = 4, n_jobs = -1, verbose = 1)

print classification_report(y, allpro_pred)
# Out:
#              precision    recall  f1-score   support
#
#     all_pro       0.19      0.30      0.23        23
# below average       0.90      0.75      0.82       220
# league_average       0.33      0.45      0.38        51
# quality starter       0.25      0.27      0.26        37
#
# avg / total       0.69      0.62      0.65       331
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.1s finished

# %%
y = df['categories'].map({'below average':0, 'league_average':1,
                          'quality starter':2, 'all_pro':3})
y.dtypes
# Out:
# dtype('int64')

# %%
from sklearn.ensemble import VotingClassifier

X = MinMaxScaler(feature_range = (1, 5)).fit_transform(year_3_refined)
y = no_dropouts['categories'].map({'below average':0, 'league_average':1,
                          'quality starter':2, 'all_pro':3})

voter_weights = [2, 2, 5, 2, 2]

voter = VotingClassifier(estimators =[
                        ('knn', knn_ideal),
                        ('nb', nb_ideal),
                        ('lr1', lr_ideal),
                        ('lr2', lr_ap),
                        ('c_svc', c_svc)
                                            ],
                        voting = 'soft',
                        weights = voter_weights)

voter_fit = voter.fit(X, y)

voter_cvp = cross_val_predict(voter_fit, X, y, cv = 4, n_jobs = -1, verbose = 1)
# Out:
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.2s finished

# %%
print classification_report(y, voter_cvp)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.82      0.85      0.83       220
#           1       0.29      0.25      0.27        51
#           2       0.26      0.24      0.25        37
#           3       0.25      0.26      0.26        23
#
# avg / total       0.63      0.65      0.64       331

# %%
print recall_score(y, voter_cvp, average = 'macro')
# Out:
# 0.401117328675

# %%
from sklearn.metrics import precision_score

print precision_score(y, voter_cvp, average = 'macro')
# Out:
# 0.404846061232

# %%
probs = voter_fit.predict_proba(X)

# %%
prob_df = pd.DataFrame(probs, index = year_3_refined.index, columns = ['below_avg', 'league_avg', 'qs', 'ap'])

# %%
prob_df.sort('ap', ascending=False)
# Out:
# /Users/TerryONeill/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                      below_avg  league_avg        qs        ap
# name
# Randy Moss            0.042712    0.065339  0.259050  0.632900
# Terrell Owens         0.025913    0.015663  0.348322  0.610102
# Marvin Harrison       0.007049    0.040251  0.343644  0.609055
# Hines Ward            0.037278    0.060373  0.355099  0.547251
# Eric Moulds           0.072978    0.118784  0.272471  0.535766
# Larry Fitzgerald      0.080280    0.097768  0.296112  0.525839
# Anquan Boldin         0.015088    0.104097  0.377575  0.503240
# Joe Horn              0.029579    0.090575  0.382480  0.497367
# Darrell Jackson       0.029173    0.055680  0.438683  0.476464
# Amani Toomer          0.119091    0.053399  0.360734  0.466775
# Julio Jones           0.092796    0.202604  0.244096  0.460504
# ...

# %% [markdown]
# # 2016 Player Predictions

# %%
rooks_preds = voter_fit.predict(rooks_year_3_refined)
rooks_preds_proba = voter_fit.predict_proba(rooks_year_3_refined)
rooks_preds_df = pd.DataFrame(rooks_preds, index = rooks_year_3_refined.index,
                            columns = ['Prediction'])
rooks_preds_df['Prediction'] = rooks_preds_df['Prediction'].map(
                                {0:'Below Average',
                                 1:'League Average',
                                 2:'Quality Starter',
                                 3:'All Pro'})
rooks_preds_proba = pd.DataFrame(rooks_preds_proba, index = rooks_year_3_refined.index,
                                columns = ['below_avg', 'league_avg', 'qual_start', 'all_pro'])

rooks_preds_df = rooks_preds_df.join(rooks_preds_proba)
print 'Number of Predictions for Each Class: \n', rooks_preds_df.Prediction.value_counts()
rooks_preds_df.sort_values('all_pro', ascending = False)
# Out:
# Number of Predictions for Each Class:
# Below Average      20
# Quality Starter    15
# League Average      9
# Name: Prediction, dtype: int64
#                             Prediction  below_avg  league_avg  qual_start  \
# Robert Woods           Quality Starter   0.051234    0.064044    0.628018
# DeAndre Hopkins        Quality Starter   0.051229    0.064129    0.628213
# Justin Hunter          Quality Starter   0.051229    0.064156    0.628229
# Terrance Williams      Quality Starter   0.025654    0.064104    0.666637
# Marquess Wilson        Quality Starter   0.025654    0.064108    0.666636
# Quinton Patton         Quality Starter   0.025654    0.064101    0.666653
# Tavon Austin           Quality Starter   0.025654    0.064082    0.666673
# Kenbrell Thompkins     Quality Starter   0.025729    0.064097    0.666790
# Denard Robinson        Quality Starter   0.015827    0.046133    0.702745
# Aaron Dobson           Quality Starter   0.089617    0.063433    0.627558
# ...
