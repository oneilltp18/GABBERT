# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('cleaned_wrs.csv')

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'name', u'season', u'age', u'draft_pos', u'team',
#        u'weight', u'bmi', u'games', u'rush_atts', u'rush_yds', u'rush_y/a',
#        u'rush_tds', u'rush_ypg', u'targets', u'receptions', u'rec_yards',
#        u'yards/reception', u'rec_tds', u'rec_ypg', u'ctch_pct', u'y/tgt',
#        u'fumbles', u'fumbles_recovered', u'fum_ret_yds', u'fum_tds',
#        u'forced_fumbles', u'pro_bowls', u'all_pros', u'position', u'100yd_gms',
#        u'yac', u'first_down_ctchs', u'first_down_ctchpct', u'long_ctch',
#        u'recs_ovr_25', u'drops', u'EYds', u'DVOA', u'DYAR', u'position.1',
#        u'Hand Size in', u'Arm Length in', u'40 Yard', u'Vert Leap in',
#        u'Broad Jump in', u'Shuttle', u'3Cone', u'60Yd Shuttle',
#        u'team_pass_tds', u'team_pass_yds', u'team_pass_attempts',
#        u'team_completions', u'rookie_age', u'rookie_season', u'height_inches',
#        u'start_ratio', u'dpis_drawn', u'dpi_yards', u'years_in_league'],
#       dtype='object')

# %%
sns.stripplot(x='years_in_league', y='receptions', data=df[df.years_in_league <=3], jitter=0.3)

# %%
sns.stripplot(x='years_in_league', y='y/tgt', data =df[df.years_in_league <=3], jitter=0.3)

# %%
for i in range(0,4):
    plt.hist(df[df.years_in_league == i]['y/tgt'], color='green', alpha=0.6)
    plt.hist(df[df.years_in_league == i]['yards/reception'], color = 'goldenrod', alpha = 0.6)
    plt.legend()
    plt.show()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'name', u'season', u'age', u'draft_pos', u'team',
#        u'weight', u'bmi', u'games', u'rush_atts', u'rush_yds', u'rush_y/a',
#        u'rush_tds', u'rush_ypg', u'targets', u'receptions', u'rec_yards',
#        u'yards/reception', u'rec_tds', u'rec_ypg', u'ctch_pct', u'y/tgt',
#        u'fumbles', u'fumbles_recovered', u'fum_ret_yds', u'fum_tds',
#        u'forced_fumbles', u'pro_bowls', u'all_pros', u'position', u'100yd_gms',
#        u'yac', u'first_down_ctchs', u'first_down_ctchpct', u'long_ctch',
#        u'recs_ovr_25', u'drops', u'EYds', u'DVOA', u'DYAR', u'position.1',
#        u'Hand Size in', u'Arm Length in', u'40 Yard', u'Vert Leap in',
#        u'Broad Jump in', u'Shuttle', u'3Cone', u'60Yd Shuttle',
#        u'team_pass_tds', u'team_pass_yds', u'team_pass_attempts',
#        u'team_completions', u'rookie_age', u'rookie_season', u'height_inches',
#        u'start_ratio', u'dpis_drawn', u'dpi_yards', u'years_in_league'],
#       dtype='object')

# %%
for i in range(0,4):
    plt.hist(df[df.years_in_league == i]['ctch_pct'], color='green', alpha=0.6)
    plt.hist(df[df.years_in_league == i]['first_down_ctchpct'], color = 'goldenrod', alpha = 0.6)
    plt.legend()
    plt.show()

# %%
for i in range(0,4):
    sns.distplot(df[df.years_in_league ==i].drops)
    plt.show()

# %%
df_15 = df[df.season == 2015]

# %%
df_15.head()
# Out:
#      Unnamed: 0               name  season   age draft_pos team  weight   bmi  \
# 129         129       Jacoby Jones  2015.0  31.0      3-73  2TM   192.0  24.0
# 130         130  Leonard Hankerson  2015.0  26.0      3-79  2TM   205.0  27.0
# 131         131       Chris Givens  2015.0  26.0      4-96  2TM   198.0  27.6
# 132         132     Chris Matthews  2015.0  26.0      UDFA  2TM   218.0  25.8
# 133         133        Jeremy Ross  2015.0  27.0      UDFA  2TM   213.0  29.7
#
#      games  rush_atts       ...         team_pass_yds  team_pass_attempts  \
# 129    9.0        0.0       ...                   NaN                 NaN
# 130   10.0        0.0       ...                   NaN                 NaN
# 131   15.0        4.0       ...                   NaN                 NaN
# 132   13.0        0.0       ...                   NaN                 NaN
# 133   11.0        1.0       ...                   NaN                 NaN
#
#      team_completions  rookie_age  rookie_season  height_inches  start_ratio  \
# 129               NaN        25.0         2009.0           75.0          0.0
# 130               NaN        22.0         2011.0           73.0          0.0
# 131               NaN        23.0         2012.0           71.0          0.4
# 132               NaN        25.0         2014.0           77.0          0.0
# 133               NaN        24.0         2012.0           71.0          0.0
#
#      dpis_drawn  dpi_yards  years_in_league
# 129         0.0        0.0              6.0
# 130         0.0        0.0              4.0
# 131         0.0        0.0              3.0
# 132         0.0        0.0              1.0
# 133         0.0        0.0              3.0
#
# [5 rows x 60 columns]

# %%
plt.scatter(df.ctch_pct, df.drops)
